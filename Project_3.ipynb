# %% [markdown]
# <a href="https://colab.research.google.com/github/lischas/myprojects/blob/main/Project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import graphviz

dot = graphviz.Graph(comment='Directions')
dot.node('A', 'Home - OKC')
dot.node('B', 'I-35')
dot.node('C', 'Wayne')
dot.node('D', 'Purcell')
dot.node('E', 'HWY 3W')
dot.node('F', 'Ada East Central')

dot.edge('A', 'B', 'East')
dot.edge('B', 'C', 'South - Construction') 
dot.edge('B', 'D', 'South')   
dot.edge('C', 'E', 'East')
dot.edge('D', 'E', 'East')
dot.edge('E', 'F', 'South then East')  
dot

# %% [markdown]
# My structure displays the route that I take to and from school. I usually check mapquest before I leave home to drive the route with the least amount of time. The construction is sometimes a problem on some days and other days it could be quicker than driving through Purcell. The 2 vertex that show 3 degrees are I-35 and HWY 3W. This is because one route enters into I-35 and travels to Wayne and Purcell while HWY 3W receives the two routes and enters into Ada East Central. This route can be considered a cycle because I usually take the same path back home. If you look at this path for a one way direction, then it wouldn't be a cycle because it wouldn't start and stop at the same vertex.

# %% [markdown]
# 2a - Converting the number 24036 with a base seven into base ten:
# (24036)base 7 = (2 * 7^4) + (4 * 7^3) + (0 * 7^2) + (3 * 7^1) + (6 * 7^0) = 4802 + 1372 + 0 + 21 + 6 =  (6201)base 10
#
#
# 2b - Converting the hexadecimal number 72e3 into base ten:        (72e3)base 16 = (7 * 16^3) + (2 * 16^2) + (14 * 16^1) + (3 * 16^0) =  28672 + 512 + 224 + 3 =  (29411)base 10

# %% [markdown]
# Converting 3735928559 into hexadecimal:

# %%
from math import floor

print(3735928559%16)
floor(3735928559/16)
# Out:
# 15
# 233495534

# %%
print(233495534%16)
floor(233495534/16)
# Out:
# 14
# 14593470

# %%
print(14593470%16)
floor(14593470/16)
# Out:
# 14
# 912091

# %%
print(912091%16)
floor(912091/16)
# Out:
# 11
# 57005

# %%
print(57005%16)
floor(57005/16)
# Out:
# 13
# 3562

# %%
print(3562%16)
floor(3562/16)
# Out:
# 10
# 222

# %%
print(222%16)
floor(222/16)
# Out:
# 14
# 13

# %%
print(13%16)
floor(13/16)
# Out:
# 13
# 0

# %% [markdown]
# 13=D, 14=E, 10=A, 13=D, 11=B, 14=E, 14=E, 15=F   WHICH SPELLS (DEADBEEF)base16

# %% [markdown]
# 2c - Base ten sbutraction 25-37, then check the answer:
# (37/2 = 18.5)     (18/2 = 9)     (9/2 = 4.5)    (4/2 = 2)     (2/2 = 1)     (1/2 = 0.5)   The binary number for 37 is 100101 or 0010 0101, by using the two's compliment and changing to a negative number...all the bits must be flipped and add 1.  (-37 = 1101 1010)
# (25/2 = 12.5)     (12/2 = 6)     (6/2 = 3)     (3/2 = 1.5)     (1/2 = 0.5)   The binary number for 25 is 11001 or 0001 1001
# 0001 1001 + 1101 1010 = 1111 0011
#
# CHECKING:
# 25-37 = -12, so... (12/2 = 6)   (6/2 = 3)   (3/2 = 1.5)   (1/2 = 0.5)      1100  or 0000 1100  for negative 12   =  1111 0011

# %% [markdown]
# The binary and hexadecimal are important to computers because all numbers stored in the system is binary. Binary has 2 digits and hexadecimal has 15 digits and the conversion between the systems is easy.
